# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing import image


model = MobileNetV2(weights='imagenet')
print("✅ MobileNetV2 Model Loaded Successfully")

print("📤 Upload an image (cat or non-cat)")
uploaded = files.upload()

for filename in uploaded.keys():

    # Load and show image
    img = image.load_img(filename, target_size=(224, 224))
    plt.imshow(img)
    plt.axis('off')

    # Preprocess image
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = tf.keras.applications.mobilenet_v2.preprocess_input(img_array)

    # Prediction
    predictions = model.predict(img_array)
    decoded_predictions = tf.keras.applications.mobilenet_v2.decode_predictions(predictions, top=5)[0]

    print("\n🔍 Top Predictions:")
    for pred in decoded_predictions:
        print(f"{pred[1]} : {pred[2]*100:.2f}%")

    # Cat detection logic
    cat_classes = [
        'tabby', 'tiger_cat', 'Persian_cat',
        'Egyptian_cat', 'Siamese_cat'
    ]

    is_cat = False
    for pred in decoded_predictions:
        for cat in cat_classes:
            if cat in pred[1]:
                is_cat = True

    # Final result
    if is_cat:
        print("\n🐱 FINAL RESULT: THIS IS A CAT")
    else:
        print("\n❌ FINAL RESULT: THIS IS NOT A CAT")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224.h5
# 14536120/14536120 ━━━━━━━━━━━━━━━━━━━━ 7s 0us/step
# ✅ MobileNetV2 Model Loaded Successfully
# 📤 Upload an image (cat or non-cat)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       9 print("✅ MobileNetV2 Model Loaded Successfully")
#      11 print("📤 Upload an image (cat or non-cat)")
# ---> 12 uploaded = files.upload()
#      14 for filename in uploaded.keys():
#      15
#      16     # Load and show image
#      17     img = image.load_img(filename, target_size=(224, 224))
#
# NameError: name 'files' is not defined
